# %%
import pandas as pd
import quandl
import os
from dotenv import load_dotenv
from quandl.errors import quandl_error
import yfinance as yf
import datetime
import requests

# %%
load_dotenv()
# Out:
# True

# %%
quandl.ApiConfig.api_key =  os.getenv("QUANDL_API_KEY")

# %%
FMP_API_KEY = os.getenv("FMP_API_KEY")

# %%
# get symbols of current secrities in the S&P 500
table=pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
SP500_df = table[0]
SP500_df.head()
# Out:
#   Symbol             Security SEC filings             GICS Sector  \
# 0    MMM           3M Company     reports             Industrials
# 1    ABT  Abbott Laboratories     reports             Health Care
# 2   ABBV          AbbVie Inc.     reports             Health Care
# 3   ABMD          ABIOMED Inc     reports             Health Care
# 4    ACN        Accenture plc     reports  Information Technology
#
#                 GICS Sub Industry    Headquarters Location Date first added  \
# 0        Industrial Conglomerates      St. Paul, Minnesota       1976-08-09
# 1           Health Care Equipment  North Chicago, Illinois       1964-03-31
# 2                 Pharmaceuticals  North Chicago, Illinois       2012-12-31
# 3           Health Care Equipment   Danvers, Massachusetts       2018-05-31
# 4  IT Consulting & Other Services          Dublin, Ireland       2011-07-06
#
#        CIK      Founded
# 0    66740         1902
# 1     1800         1888
# 2  1551152  2013 (1888)
# ...

# %%
start = datetime.datetime(2014,1,1)
end = datetime.datetime(2020,9,1)
data = yf.download(SP500_df['Symbol'].to_list(), start=start, end=end)
# Out:
# [*********************100%***********************]  505 of 505 completed
#
# 2 Failed downloads:
# - BF.B: No data found for this date range, symbol may be delisted
# - BRK.B: No data found, symbol may be delisted

# %%
data['Open']['AAPL'].tail()
# Out:
# Date
# 2020-08-26    126.180000
# 2020-08-27    127.142502
# 2020-08-28    126.012497
# 2020-08-31    127.580002
# 2020-09-01           NaN
# Name: AAPL, dtype: float64

# %%
msft = yf.Ticker("MSFT")

msft.balancesheet
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
r = requests.get(f'https://financialmodelingprep.com/api/v3/ratios/AAPL?limit=40&apikey={FMP_API_KEY}')
r.json()
# Out:
# [{'symbol': 'AAPL',
#   'date': '2019-09-28',
#   'currentRatio': 1.540125617208044,
#   'quickRatio': 1.3844473032028604,
#   'cashRatio': 0.46202160464632325,
#   'daysOfSalesOutstanding': 64.25876528784583,
#   'daysOfInventoryOutstanding': 9.263638723714628,
#   'operatingCycle': 73.52240401156047,
#   'daysOfPayablesOutstanding': 104.31407696777144,
#   'cashConversionCycle': -30.791672956210974,
#   'grossProfitMargin': 0.3781776810903472,
#   'operatingProfitMargin': 0.24572017188496928,
#   'pretaxProfitMargin': 0.2526655238417367,
#   'netProfitMargin': 0.21238094505984456,
#   'effectiveTaxRate': 0.1594383680423506,
#   'returnOnAssets': 0.16323009842961633,
#   'returnOnEquity': 0.6106445053487756,
#   'returnOnCapitalEmployed': 0.28237785547985805,
#   'netIncomePerEBT': 0.8405616319576494,
#   'ebtPerEbit': 1,
#   'ebitPerRevenue': 0.2526655238417367,
#   'debtRatio': 0.7326921031797611,
#   'debtEquityRatio': 2.7410043320661304,
# ...
